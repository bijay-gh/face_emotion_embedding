# %%
from os import listdir
from os.path import isfile, join
import shutil
import os
from pathlib import Path

# %%
root_dir = Path.cwd()
dataset_root = Path(root_dir ,'RWD_Dataset')
emo_label_path = Path(root_dir, 'EmoLabel\list_patition_label.txt')
image_path = Path(root_dir, 'Image/aligned')

# %%
emotion_dict = {
    1: "Surprise",
    2: "Fear",
    3: "Disgust",
    4: "Happiness",
    5: "Sadness",
    6: "Anger",
    7: "Neutral",

}

# %%
# dataset_root
dataset_root.mkdir(parents=True, exist_ok=True)
for emotion in emotion_dict.values():
    emotion_dir = dataset_root / emotion
    emotion_dir.mkdir(parents=True, exist_ok=True)
    print(f"Created {emotion_dir}")
# Out:
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Surprise
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Fear
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Disgust
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Happiness
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Sadness
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Anger
# Created e:\Projects\Emotion_Classification\RAF_DB\Single_Emotion\RWD_Dataset\Neutral

# %%
# Counting the images in each emotion and total number of emotions
from collections import Counter
counter = Counter()

with open(emo_label_path, 'r') as f:
    lines = f.readlines()
    for line in lines:
        line = line.strip()
        line = line.split(' ')
        try:
            emotion_id = int(line[1])
            emotion = emotion_dict[emotion_id]
            counter[emotion] += 1
        except ValueError:
            continue
            
for emotion, count in counter.items():
    print(f"{emotion}: {count}")

print(f"\nTotal unique emotions: {len(counter)}")
# Out:
# Sadness: 2460
# Happiness: 5957
# Surprise: 1619
# Anger: 867
# Fear: 355
# Disgust: 877
# Neutral: 3204
#
# Total unique emotions: 7

# %%
def get_aligned_image_name(image_name):
    stem = Path(image_name).stem
    suffix = Path(image_name).suffix
    return f"{stem}_aligned{suffix}"

# %%
# Read label file and move images
with emo_label_path.open('r') as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) < 2:
            continue

        image_name = parts[0]
        try:
            emotion_id = int(parts[1])
            emotion = emotion_dict.get(emotion_id)
            if emotion is None:
                print(f"Unknown emotion ID: {emotion_id} for {image_name}")
                continue

            image_name = get_aligned_image_name(image_name)
            src_path = image_path / image_name
            dest_folder = dataset_root / emotion
            dest_path = dest_folder / image_name

            # Create the destination folder if needed
            dest_folder.mkdir(parents=True, exist_ok=True)

            # Move the image
            if src_path.exists():
                shutil.copy(str(src_path), str(dest_path))
                print(f"Copied {image_name} → {emotion}/")
            else:
                print(f"File not found: {src_path}")

        except ValueError:
            print(f"Invalid line format: {line.strip()}")
# Out:
# Copied train_00001_aligned.jpg → Sadness/
# Copied train_00002_aligned.jpg → Sadness/
# Copied train_00003_aligned.jpg → Happiness/
# Copied train_00004_aligned.jpg → Happiness/
# Copied train_00005_aligned.jpg → Sadness/
# Copied train_00006_aligned.jpg → Surprise/
# Copied train_00007_aligned.jpg → Sadness/
# Copied train_00008_aligned.jpg → Happiness/
# Copied train_00009_aligned.jpg → Happiness/
# Copied train_00010_aligned.jpg → Surprise/
# Copied train_00011_aligned.jpg → Happiness/
# Copied train_00012_aligned.jpg → Surprise/
# Copied train_00013_aligned.jpg → Surprise/
# Copied train_00014_aligned.jpg → Happiness/
# Copied train_00015_aligned.jpg → Sadness/
# Copied train_00016_aligned.jpg → Happiness/
# Copied train_00017_aligned.jpg → Happiness/
# Copied train_00018_aligned.jpg → Happiness/
# Copied train_00019_aligned.jpg → Happiness/
# Copied train_00020_aligned.jpg → Happiness/
# Copied train_00021_aligned.jpg → Happiness/
# Copied train_00022_aligned.jpg → Happiness/
# Copied train_00023_aligned.jpg → Anger/
# Copied train_00024_aligned.jpg → Sadness/
# Copied train_00025_aligned.jpg → Sadness/
# Copied train_00026_aligned.jpg → Sadness/
# Copied train_00027_aligned.jpg → Fear/
# Copied train_00028_aligned.jpg → Sadness/
# Copied train_00029_aligned.jpg → Happiness/
# Copied train_00030_aligned.jpg → Sadness/
# Copied train_00031_aligned.jpg → Disgust/
# Copied train_00032_aligned.jpg → Surprise/
# Copied train_00033_aligned.jpg → Sadness/
# Copied train_00034_aligned.jpg → Surprise/
# Copied train_00035_aligned.jpg → Happiness/
# Copied train_00036_aligned.jpg → Happiness/
# Copied train_00037_aligned.jpg → Happiness/
# Copied train_00038_aligned.jpg → Sadness/
# Copied train_00039_aligned.jpg → Sadness/
# Copied train_00040_aligned.jpg → Sadness/
# Copied train_00041_aligned.jpg → Sadness/
# Copied train_00042_aligned.jpg → Sadness/
# Copied train_00043_aligned.jpg → Surprise/
# Copied train_00044_aligned.jpg → Surprise/
# Copied train_00045_aligned.jpg → Happiness/
# Copied train_00046_aligned.jpg → Happiness/
# Copied train_00047_aligned.jpg → Anger/
# Copied train_00048_aligned.jpg → Happiness/
# Copied train_00049_aligned.jpg → Anger/
# Copied train_00050_aligned.jpg → Happiness/
# Copied train_00051_aligned.jpg → Happiness/
# Copied train_00052_aligned.jpg → Happiness/
# Copied train_00053_aligned.jpg → Surprise/
# Copied train_00054_aligned.jpg → Happiness/
# Copied train_00055_aligned.jpg → Happiness/
# Copied train_00056_aligned.jpg → Happiness/
# Copied train_00057_aligned.jpg → Happiness/
# Copied train_00058_aligned.jpg → Happiness/
# Copied train_00059_aligned.jpg → Happiness/
# Copied train_00060_aligned.jpg → Happiness/
# Copied train_00061_aligned.jpg → Happiness/
# Copied train_00062_aligned.jpg → Surprise/
# Copied train_00063_aligned.jpg → Disgust/
# Copied train_00064_aligned.jpg → Anger/
# Copied train_00065_aligned.jpg → Happiness/
# Copied train_00066_aligned.jpg → Sadness/
# Copied train_00067_aligned.jpg → Happiness/
# Copied train_00068_aligned.jpg → Surprise/
# Copied train_00069_aligned.jpg → Surprise/
# Copied train_00070_aligned.jpg → Anger/
# Copied train_00071_aligned.jpg → Disgust/
# Copied train_00072_aligned.jpg → Surprise/
# Copied train_00073_aligned.jpg → Happiness/
# Copied train_00074_aligned.jpg → Happiness/
# Copied train_00075_aligned.jpg → Happiness/
# Copied train_00076_aligned.jpg → Happiness/
# Copied train_00077_aligned.jpg → Happiness/
# Copied train_00078_aligned.jpg → Happiness/
# Copied train_00079_aligned.jpg → Happiness/
# Copied train_00080_aligned.jpg → Happiness/
# Copied train_00081_aligned.jpg → Disgust/
# Copied train_00082_aligned.jpg → Happiness/
# Copied train_00083_aligned.jpg → Happiness/
# Copied train_00084_aligned.jpg → Happiness/
# Copied train_00085_aligned.jpg → Happiness/
# Copied train_00086_aligned.jpg → Happiness/
# Copied train_00087_aligned.jpg → Happiness/
# Copied train_00088_aligned.jpg → Sadness/
# Copied train_00089_aligned.jpg → Happiness/
# Copied train_00090_aligned.jpg → Happiness/
# Copied train_00091_aligned.jpg → Surprise/
# Copied train_00092_aligned.jpg → Happiness/
# Copied train_00093_aligned.jpg → Happiness/
# Copied train_00094_aligned.jpg → Happiness/
# Copied train_00095_aligned.jpg → Anger/
# Copied train_00096_aligned.jpg → Happiness/
# Copied train_00097_aligned.jpg → Sadness/
# Copied train_00098_aligned.jpg → Happiness/
# Copied train_00099_aligned.jpg → Happiness/
# Copied train_00100_aligned.jpg → Happiness/
# Copied train_00101_aligned.jpg → Sadness/
# Copied train_00102_aligned.jpg → Sadness/
# Copied train_00103_aligned.jpg → Disgust/
# Copied train_00104_aligned.jpg → Surprise/
# Copied train_00105_aligned.jpg → Anger/
# Copied train_00106_aligned.jpg → Surprise/
# Copied train_00107_aligned.jpg → Surprise/
# Copied train_00108_aligned.jpg → Happiness/
# Copied train_00109_aligned.jpg → Sadness/
# Copied train_00110_aligned.jpg → Surprise/
# Copied train_00111_aligned.jpg → Surprise/
# Copied train_00112_aligned.jpg → Surprise/
# Copied train_00113_aligned.jpg → Surprise/
# Copied train_00114_aligned.jpg → Surprise/
# Copied train_00115_aligned.jpg → Sadness/
# Copied train_00116_aligned.jpg → Happiness/
# Copied train_00117_aligned.jpg → Happiness/
# Copied train_00118_aligned.jpg → Anger/
# Copied train_00119_aligned.jpg → Sadness/
# Copied train_00120_aligned.jpg → Disgust/
# Copied train_00121_aligned.jpg → Happiness/
# Copied train_00122_aligned.jpg → Happiness/
# Copied train_00123_aligned.jpg → Happiness/
# Copied train_00124_aligned.jpg → Happiness/
# Copied train_00125_aligned.jpg → Surprise/
# Copied train_00126_aligned.jpg → Surprise/
# Copied train_00127_aligned.jpg → Happiness/
# Copied train_00128_aligned.jpg → Happiness/
# Copied train_00129_aligned.jpg → Surprise/
# Copied train_00130_aligned.jpg → Sadness/
# Copied train_00131_aligned.jpg → Anger/
# Copied train_00132_aligned.jpg → Happiness/
# Copied train_00133_aligned.jpg → Happiness/
# Copied train_00134_aligned.jpg → Anger/
# Copied train_00135_aligned.jpg → Happiness/
# Copied train_00136_aligned.jpg → Surprise/
# Copied train_00137_aligned.jpg → Surprise/
# Copied train_00138_aligned.jpg → Happiness/
# Copied train_00139_aligned.jpg → Sadness/
# Copied train_00140_aligned.jpg → Anger/
# Copied train_00141_aligned.jpg → Happiness/
# Copied train_00142_aligned.jpg → Sadness/
# Copied train_00143_aligned.jpg → Anger/
# Copied train_00144_aligned.jpg → Sadness/
# Copied train_00145_aligned.jpg → Anger/
# Copied train_00146_aligned.jpg → Happiness/
# Copied train_00147_aligned.jpg → Surprise/
# Copied train_00148_aligned.jpg → Happiness/
# Copied train_00149_aligned.jpg → Happiness/
# Copied train_00150_aligned.jpg → Anger/
# Copied train_00151_aligned.jpg → Surprise/
# Copied train_00152_aligned.jpg → Happiness/
# Copied train_00153_aligned.jpg → Happiness/
# Copied train_00154_aligned.jpg → Surprise/
# Copied train_00155_aligned.jpg → Sadness/
# Copied train_00156_aligned.jpg → Surprise/
# Copied train_00157_aligned.jpg → Anger/
# Copied train_00158_aligned.jpg → Sadness/
# Copied train_00159_aligned.jpg → Happiness/
# Copied train_00160_aligned.jpg → Sadness/
# Copied train_00161_aligned.jpg → Happiness/
# Copied train_00162_aligned.jpg → Happiness/
# Copied train_00163_aligned.jpg → Sadness/
# Copied train_00164_aligned.jpg → Anger/
# Copied train_00165_aligned.jpg → Sadness/
# Copied train_00166_aligned.jpg → Surprise/
# Copied train_00167_aligned.jpg → Happiness/
# Copied train_00168_aligned.jpg → Happiness/
# Copied train_00169_aligned.jpg → Happiness/
# Copied train_00170_aligned.jpg → Surprise/
# Copied train_00171_aligned.jpg → Sadness/
# Copied train_00172_aligned.jpg → Happiness/
# Copied train_00173_aligned.jpg → Happiness/
# Copied train_00174_aligned.jpg → Happiness/
# Copied train_00175_aligned.jpg → Surprise/
# Copied train_00176_aligned.jpg → Happiness/
# Copied train_00177_aligned.jpg → Happiness/
# Copied train_00178_aligned.jpg → Happiness/
# Copied train_00179_aligned.jpg → Happiness/
# Copied train_00180_aligned.jpg → Happiness/
# Copied train_00181_aligned.jpg → Surprise/
# Copied train_00182_aligned.jpg → Surprise/
# Copied train_00183_aligned.jpg → Happiness/
# Copied train_00184_aligned.jpg → Happiness/
# Copied train_00185_aligned.jpg → Happiness/
# Copied train_00186_aligned.jpg → Disgust/
# Copied train_00187_aligned.jpg → Happiness/
# Copied train_00188_aligned.jpg → Happiness/
# Copied train_00189_aligned.jpg → Happiness/
# Copied train_00190_aligned.jpg → Happiness/
# Copied train_00191_aligned.jpg → Happiness/
# Copied train_00192_aligned.jpg → Happiness/
# Copied train_00193_aligned.jpg → Happiness/
# Copied train_00194_aligned.jpg → Sadness/
# Copied train_00195_aligned.jpg → Happiness/
# Copied train_00196_aligned.jpg → Happiness/
# Copied train_00197_aligned.jpg → Happiness/
# Copied train_00198_aligned.jpg → Happiness/
# Copied train_00199_aligned.jpg → Sadness/
# Copied train_00200_aligned.jpg → Surprise/
# Copied train_00201_aligned.jpg → Happiness/
# Copied train_00202_aligned.jpg → Happiness/
# Copied train_00203_aligned.jpg → Happiness/
# Copied train_00204_aligned.jpg → Surprise/
# Copied train_00205_aligned.jpg → Happiness/
# Copied train_00206_aligned.jpg → Anger/
# Copied train_00207_aligned.jpg → Disgust/
# Copied train_00208_aligned.jpg → Anger/
# Copied train_00209_aligned.jpg → Happiness/
# Copied train_00210_aligned.jpg → Happiness/
# Copied train_00211_aligned.jpg → Happiness/
# Copied train_00212_aligned.jpg → Happiness/
# Copied train_00213_aligned.jpg → Surprise/
# Copied train_00214_aligned.jpg → Sadness/
# Copied train_00215_aligned.jpg → Happiness/
# Copied train_00216_aligned.jpg → Sadness/
# Copied train_00217_aligned.jpg → Disgust/
# Copied train_00218_aligned.jpg → Disgust/
# Copied train_00219_aligned.jpg → Happiness/
# Copied train_00220_aligned.jpg → Happiness/
# Copied train_00221_aligned.jpg → Sadness/
# Copied train_00222_aligned.jpg → Sadness/
# Copied train_00223_aligned.jpg → Surprise/
# Copied train_00224_aligned.jpg → Happiness/
# Copied train_00225_aligned.jpg → Happiness/
# Copied train_00226_aligned.jpg → Happiness/
# Copied train_00227_aligned.jpg → Happiness/
# Copied train_00228_aligned.jpg → Happiness/
# Copied train_00229_aligned.jpg → Happiness/
# Copied train_00230_aligned.jpg → Surprise/
# Copied train_00231_aligned.jpg → Sadness/
# Copied train_00232_aligned.jpg → Happiness/
# Copied train_00233_aligned.jpg → Happiness/
# Copied train_00234_aligned.jpg → Happiness/
# Copied train_00235_aligned.jpg → Happiness/
# Copied train_00236_aligned.jpg → Sadness/
# Copied train_00237_aligned.jpg → Anger/
# Copied train_00238_aligned.jpg → Sadness/
# Copied train_00239_aligned.jpg → Surprise/
# Copied train_00240_aligned.jpg → Happiness/
# Copied train_00241_aligned.jpg → Happiness/
# Copied train_00242_aligned.jpg → Sadness/
# Copied train_00243_aligned.jpg → Surprise/
# Copied train_00244_aligned.jpg → Happiness/
# Copied train_00245_aligned.jpg → Happiness/
# Copied train_00246_aligned.jpg → Happiness/
# Copied train_00247_aligned.jpg → Surprise/
# Copied train_00248_aligned.jpg → Sadness/
# Copied train_00249_aligned.jpg → Sadness/
# Copied train_00250_aligned.jpg → Happiness/
# Copied train_00251_aligned.jpg → Sadness/
# Copied train_00252_aligned.jpg → Sadness/
# Copied train_00253_aligned.jpg → Sadness/
# Copied train_00254_aligned.jpg → Happiness/
# Copied train_00255_aligned.jpg → Happiness/
# Copied train_00256_aligned.jpg → Happiness/
# Copied train_00257_aligned.jpg → Happiness/
# Copied train_00258_aligned.jpg → Happiness/
# Copied train_00259_aligned.jpg → Surprise/
# Copied train_00260_aligned.jpg → Happiness/
# Copied train_00261_aligned.jpg → Surprise/
# Copied train_00262_aligned.jpg → Sadness/
# Copied train_00263_aligned.jpg → Sadness/
# Copied train_00264_aligned.jpg → Happiness/
# Copied train_00265_aligned.jpg → Happiness/
# Copied train_00266_aligned.jpg → Happiness/
# Copied train_00267_aligned.jpg → Happiness/
# Copied train_00268_aligned.jpg → Happiness/
# Copied train_00269_aligned.jpg → Sadness/
# Copied train_00270_aligned.jpg → Surprise/
# Copied train_00271_aligned.jpg → Sadness/
# Copied train_00272_aligned.jpg → Sadness/
# Copied train_00273_aligned.jpg → Sadness/
# Copied train_00274_aligned.jpg → Happiness/
# Copied train_00275_aligned.jpg → Happiness/
# Copied train_00276_aligned.jpg → Happiness/
# Copied train_00277_aligned.jpg → Sadness/
# Copied train_00278_aligned.jpg → Surprise/
# Copied train_00279_aligned.jpg → Happiness/
# Copied train_00280_aligned.jpg → Happiness/
# Copied train_00281_aligned.jpg → Happiness/
# Copied train_00282_aligned.jpg → Happiness/
# Copied train_00283_aligned.jpg → Sadness/
# Copied train_00284_aligned.jpg → Sadness/
# Copied train_00285_aligned.jpg → Sadness/
# Copied train_00286_aligned.jpg → Sadness/
# Copied train_00287_aligned.jpg → Sadness/
# Copied train_00288_aligned.jpg → Sadness/
# Copied train_00289_aligned.jpg → Sadness/
# Copied train_00290_aligned.jpg → Happiness/
# Copied train_00291_aligned.jpg → Sadness/
# Copied train_00292_aligned.jpg → Happiness/
# Copied train_00293_aligned.jpg → Happiness/
# Copied train_00294_aligned.jpg → Disgust/
# Copied train_00295_aligned.jpg → Anger/
# Copied train_00296_aligned.jpg → Disgust/
# Copied train_00297_aligned.jpg → Surprise/
# Copied train_00298_aligned.jpg → Happiness/
# Copied train_00299_aligned.jpg → Sadness/
# Copied train_00300_aligned.jpg → Happiness/
# Copied train_00301_aligned.jpg → Happiness/
# Copied train_00302_aligned.jpg → Happiness/
# Copied train_00303_aligned.jpg → Happiness/
# Copied train_00304_aligned.jpg → Surprise/
# Copied train_00305_aligned.jpg → Sadness/
# Copied train_00306_aligned.jpg → Sadness/
# Copied train_00307_aligned.jpg → Happiness/
# Copied train_00308_aligned.jpg → Happiness/
# Copied train_00309_aligned.jpg → Happiness/
# Copied train_00310_aligned.jpg → Happiness/
# Copied train_00311_aligned.jpg → Happiness/
# Copied train_00312_aligned.jpg → Happiness/
# Copied train_00313_aligned.jpg → Happiness/
# Copied train_00314_aligned.jpg → Happiness/
# Copied train_00315_aligned.jpg → Happiness/
# Copied train_00316_aligned.jpg → Happiness/
# Copied train_00317_aligned.jpg → Happiness/
# Copied train_00318_aligned.jpg → Happiness/
# Copied train_00319_aligned.jpg → Sadness/
# Copied train_00320_aligned.jpg → Happiness/
# Copied train_00321_aligned.jpg → Anger/
# Copied train_00322_aligned.jpg → Sadness/
# Copied train_00323_aligned.jpg → Surprise/
# Copied train_00324_aligned.jpg → Surprise/
# Copied train_00325_aligned.jpg → Sadness/
# Copied train_00326_aligned.jpg → Happiness/
# Copied train_00327_aligned.jpg → Happiness/
# Copied train_00328_aligned.jpg → Surprise/
# Copied train_00329_aligned.jpg → Happiness/
# Copied train_00330_aligned.jpg → Happiness/
# Copied train_00331_aligned.jpg → Happiness/
# Copied train_00332_aligned.jpg → Happiness/
# Copied train_00333_aligned.jpg → Happiness/
# Copied train_00334_aligned.jpg → Happiness/
# Copied train_00335_aligned.jpg → Happiness/
# Copied train_00336_aligned.jpg → Sadness/
# Copied train_00337_aligned.jpg → Happiness/
# Copied train_00338_aligned.jpg → Happiness/
# Copied train_00339_aligned.jpg → Anger/
# Copied train_00340_aligned.jpg → Anger/
# Copied train_00341_aligned.jpg → Surprise/
# Copied train_00342_aligned.jpg → Sadness/
# Copied train_00343_aligned.jpg → Surprise/
# Copied train_00344_aligned.jpg → Happiness/
# Copied train_00345_aligned.jpg → Sadness/
# Copied train_00346_aligned.jpg → Happiness/
# Copied train_00347_aligned.jpg → Sadness/
# Copied train_00348_aligned.jpg → Happiness/
# Copied train_00349_aligned.jpg → Sadness/
# Copied train_00350_aligned.jpg → Happiness/
# Copied train_00351_aligned.jpg → Happiness/
# Copied train_00352_aligned.jpg → Happiness/
# Copied train_00353_aligned.jpg → Happiness/
# Copied train_00354_aligned.jpg → Surprise/
# Copied train_00355_aligned.jpg → Happiness/
# Copied train_00356_aligned.jpg → Sadness/
# Copied train_00357_aligned.jpg → Happiness/
# Copied train_00358_aligned.jpg → Happiness/
# Copied train_00359_aligned.jpg → Surprise/
# Copied train_00360_aligned.jpg → Happiness/
# Copied train_00361_aligned.jpg → Anger/
# Copied train_00362_aligned.jpg → Anger/
# Copied train_00363_aligned.jpg → Happiness/
# Copied train_00364_aligned.jpg → Sadness/
# Copied train_00365_aligned.jpg → Happiness/
# Copied train_00366_aligned.jpg → Happiness/
# Copied train_00367_aligned.jpg → Happiness/
# Copied train_00368_aligned.jpg → Happiness/
# Copied train_00369_aligned.jpg → Sadness/
# Copied train_00370_aligned.jpg → Sadness/
# Copied train_00371_aligned.jpg → Sadness/
# Copied train_00372_aligned.jpg → Surprise/
# Copied train_00373_aligned.jpg → Happiness/
# Copied train_00374_aligned.jpg → Happiness/
# Copied train_00375_aligned.jpg → Happiness/
# Copied train_00376_aligned.jpg → Anger/
# Copied train_00377_aligned.jpg → Happiness/
# Copied train_00378_aligned.jpg → Happiness/
# Copied train_00379_aligned.jpg → Surprise/
# Copied train_00380_aligned.jpg → Surprise/
# Copied train_00381_aligned.jpg → Happiness/
# Copied train_00382_aligned.jpg → Sadness/
# Copied train_00383_aligned.jpg → Surprise/
# Copied train_00384_aligned.jpg → Anger/
# Copied train_00385_aligned.jpg → Happiness/
# Copied train_00386_aligned.jpg → Sadness/
# Copied train_00387_aligned.jpg → Sadness/
# Copied train_00388_aligned.jpg → Happiness/
# Copied train_00389_aligned.jpg → Happiness/
# Copied train_00390_aligned.jpg → Happiness/
# Copied train_00391_aligned.jpg → Sadness/
# Copied train_00392_aligned.jpg → Happiness/
# Copied train_00393_aligned.jpg → Happiness/
# Copied train_00394_aligned.jpg → Happiness/
# Copied train_00395_aligned.jpg → Happiness/
# Copied train_00396_aligned.jpg → Happiness/
# Copied train_00397_aligned.jpg → Happiness/
# Copied train_00398_aligned.jpg → Sadness/
# Copied train_00399_aligned.jpg → Surprise/
# Copied train_00400_aligned.jpg → Surprise/
# Copied train_00401_aligned.jpg → Happiness/
# Copied train_00402_aligned.jpg → Happiness/
# Copied train_00403_aligned.jpg → Happiness/
# Copied train_00404_aligned.jpg → Happiness/
# Copied train_00405_aligned.jpg → Happiness/
# Copied train_00406_aligned.jpg → Happiness/
# Copied train_00407_aligned.jpg → Happiness/
# Copied train_00408_aligned.jpg → Surprise/
# Copied train_00409_aligned.jpg → Happiness/
# Copied train_00410_aligned.jpg → Happiness/
# Copied train_00411_aligned.jpg → Happiness/
# Copied train_00412_aligned.jpg → Happiness/
# Copied train_00413_aligned.jpg → Happiness/
# Copied train_00414_aligned.jpg → Happiness/
# Copied train_00415_aligned.jpg → Happiness/
# Copied train_00416_aligned.jpg → Happiness/
# Copied train_00417_aligned.jpg → Disgust/
# Copied train_00418_aligned.jpg → Anger/
# Copied train_00419_aligned.jpg → Anger/
# Copied train_00420_aligned.jpg → Happiness/
# Copied train_00421_aligned.jpg → Anger/
# Copied train_00422_aligned.jpg → Anger/
# Copied train_00423_aligned.jpg → Sadness/
# Copied train_00424_aligned.jpg → Surprise/
# Copied train_00425_aligned.jpg → Happiness/
# Copied train_00426_aligned.jpg → Happiness/
# Copied train_00427_aligned.jpg → Anger/
# Copied train_00428_aligned.jpg → Anger/
# Copied train_00429_aligned.jpg → Sadness/
# Copied train_00430_aligned.jpg → Happiness/
# Copied train_00431_aligned.jpg → Sadness/
# Copied train_00432_aligned.jpg → Happiness/
# Copied train_00433_aligned.jpg → Happiness/
# Copied train_00434_aligned.jpg → Happiness/
# Copied train_00435_aligned.jpg → Happiness/
# Copied train_00436_aligned.jpg → Sadness/
# Copied train_00437_aligned.jpg → Anger/
# Copied train_00438_aligned.jpg → Happiness/
# Copied train_00439_aligned.jpg → Happiness/
# Copied train_00440_aligned.jpg → Happiness/
# Copied train_00441_aligned.jpg → Happiness/
# Copied train_00442_aligned.jpg → Surprise/
# Copied train_00443_aligned.jpg → Happiness/
# Copied train_00444_aligned.jpg → Disgust/
# Copied train_00445_aligned.jpg → Sadness/
# Copied train_00446_aligned.jpg → Happiness/
# Copied train_00447_aligned.jpg → Disgust/
# Copied train_00448_aligned.jpg → Happiness/
# Copied train_00449_aligned.jpg → Happiness/
# Copied train_00450_aligned.jpg → Surprise/
# Copied train_00451_aligned.jpg → Sadness/
# Copied train_00452_aligned.jpg → Happiness/
# Copied train_00453_aligned.jpg → Happiness/
# Copied train_00454_aligned.jpg → Happiness/
# Copied train_00455_aligned.jpg → Happiness/
# Copied train_00456_aligned.jpg → Happiness/
# Copied train_00457_aligned.jpg → Happiness/
# Copied train_00458_aligned.jpg → Anger/
# Copied train_00459_aligned.jpg → Sadness/
# Copied train_00460_aligned.jpg → Sadness/
# Copied train_00461_aligned.jpg → Anger/
# Copied train_00462_aligned.jpg → Happiness/
# Copied train_00463_aligned.jpg → Surprise/
# Copied train_00464_aligned.jpg → Sadness/
# Copied train_00465_aligned.jpg → Surprise/
# Copied train_00466_aligned.jpg → Happiness/
# Copied train_00467_aligned.jpg → Happiness/
# Copied train_00468_aligned.jpg → Happiness/
# Copied train_00469_aligned.jpg → Happiness/
# Copied train_00470_aligned.jpg → Happiness/
# Copied train_00471_aligned.jpg → Anger/
# Copied train_00472_aligned.jpg → Happiness/
# Copied train_00473_aligned.jpg → Sadness/
# Copied train_00474_aligned.jpg → Surprise/
# Copied train_00475_aligned.jpg → Anger/
# Copied train_00476_aligned.jpg → Sadness/
# Copied train_00477_aligned.jpg → Sadness/
# Copied train_00478_aligned.jpg → Happiness/
# Copied train_00479_aligned.jpg → Sadness/
# Copied train_00480_aligned.jpg → Happiness/
# Copied train_00481_aligned.jpg → Happiness/
# Copied train_00482_aligned.jpg → Surprise/
# Copied train_00483_aligned.jpg → Happiness/
# Copied train_00484_aligned.jpg → Happiness/
# Copied train_00485_aligned.jpg → Happiness/
# Copied train_00486_aligned.jpg → Happiness/
# Copied train_00487_aligned.jpg → Happiness/
# Copied train_00488_aligned.jpg → Sadness/
# Copied train_00489_aligned.jpg → Disgust/
# Copied train_00490_aligned.jpg → Happiness/
# Copied train_00491_aligned.jpg → Happiness/
# Copied train_00492_aligned.jpg → Anger/
# Copied train_00493_aligned.jpg → Happiness/
# Copied train_00494_aligned.jpg → Happiness/
# Copied train_00495_aligned.jpg → Happiness/
# Copied train_00496_aligned.jpg → Sadness/
# Copied train_00497_aligned.jpg → Happiness/
# Copied train_00498_aligned.jpg → Happiness/
# Copied train_00499_aligned.jpg → Happiness/
# Copied train_00500_aligned.jpg → Sadness/
# Copied train_00501_aligned.jpg → Anger/
# Copied train_00502_aligned.jpg → Happiness/
# Copied train_00503_aligned.jpg → Happiness/
# Copied train_00504_aligned.jpg → Happiness/
# Copied train_00505_aligned.jpg → Happiness/
# Copied train_00506_aligned.jpg → Happiness/
# Copied train_00507_aligned.jpg → Surprise/
# Copied train_00508_aligned.jpg → Happiness/
# Copied train_00509_aligned.jpg → Surprise/
# Copied train_00510_aligned.jpg → Anger/
# Copied train_00511_aligned.jpg → Sadness/
# Copied train_00512_aligned.jpg → Sadness/
# Copied train_00513_aligned.jpg → Happiness/
# Copied train_00514_aligned.jpg → Happiness/
# Copied train_00515_aligned.jpg → Happiness/
# Copied train_00516_aligned.jpg → Happiness/
# Copied train_00517_aligned.jpg → Disgust/
# Copied train_00518_aligned.jpg → Happiness/
# Copied train_00519_aligned.jpg → Happiness/
# Copied train_00520_aligned.jpg → Surprise/
# Copied train_00521_aligned.jpg → Happiness/
# Copied train_00522_aligned.jpg → Happiness/
# Copied train_00523_aligned.jpg → Happiness/
# Copied train_00524_aligned.jpg → Happiness/
# Copied train_00525_aligned.jpg → Happiness/
# Copied train_00526_aligned.jpg → Sadness/
# Copied train_00527_aligned.jpg → Happiness/
# Copied train_00528_aligned.jpg → Happiness/
# Copied train_00529_aligned.jpg → Happiness/
# Copied train_00530_aligned.jpg → Happiness/
# Copied train_00531_aligned.jpg → Sadness/
# Copied train_00532_aligned.jpg → Happiness/
# Copied train_00533_aligned.jpg → Disgust/
# Copied train_00534_aligned.jpg → Sadness/
# Copied train_00535_aligned.jpg → Sadness/
# Copied train_00536_aligned.jpg → Sadness/
# Copied train_00537_aligned.jpg → Happiness/
# Copied train_00538_aligned.jpg → Happiness/
# Copied train_00539_aligned.jpg → Surprise/
# Copied train_00540_aligned.jpg → Sadness/
# Copied train_00541_aligned.jpg → Happiness/
# Copied train_00542_aligned.jpg → Happiness/
# Copied train_00543_aligned.jpg → Surprise/
# Copied train_00544_aligned.jpg → Sadness/
# Copied train_00545_aligned.jpg → Happiness/
# Copied train_00546_aligned.jpg → Happiness/
# Copied train_00547_aligned.jpg → Happiness/
# Copied train_00548_aligned.jpg → Happiness/
# Copied train_00549_aligned.jpg → Happiness/
# Copied train_00550_aligned.jpg → Sadness/
# Copied train_00551_aligned.jpg → Disgust/
# Copied train_00552_aligned.jpg → Disgust/
# Copied train_00553_aligned.jpg → Disgust/
# Copied train_00554_aligned.jpg → Disgust/
# Copied train_00555_aligned.jpg → Happiness/
# Copied train_00556_aligned.jpg → Disgust/
# Copied train_00557_aligned.jpg → Sadness/
# Copied train_00558_aligned.jpg → Sadness/
# Copied train_00559_aligned.jpg → Sadness/
# Copied train_00560_aligned.jpg → Sadness/
# Copied train_00561_aligned.jpg → Happiness/
# Copied train_00562_aligned.jpg → Sadness/
# Copied train_00563_aligned.jpg → Sadness/
# Copied train_00564_aligned.jpg → Anger/
# Copied train_00565_aligned.jpg → Happiness/
# Copied train_00566_aligned.jpg → Sadness/
# Copied train_00567_aligned.jpg → Sadness/
# Copied train_00568_aligned.jpg → Surprise/
# Copied train_00569_aligned.jpg → Happiness/
# Copied train_00570_aligned.jpg → Happiness/
# Copied train_00571_aligned.jpg → Happiness/
# Copied train_00572_aligned.jpg → Surprise/
# Copied train_00573_aligned.jpg → Sadness/
# Copied train_00574_aligned.jpg → Sadness/
# Copied train_00575_aligned.jpg → Sadness/
# Copied train_00576_aligned.jpg → Surprise/
# Copied train_00577_aligned.jpg → Surprise/
# Copied train_00578_aligned.jpg → Anger/
# Copied train_00579_aligned.jpg → Anger/
# Copied train_00580_aligned.jpg → Happiness/
# Copied train_00581_aligned.jpg → Happiness/
# Copied train_00582_aligned.jpg → Happiness/
# Copied train_00583_aligned.jpg → Sadness/
# Copied train_00584_aligned.jpg → Surprise/
# Copied train_00585_aligned.jpg → Sadness/
# Copied train_00586_aligned.jpg → Surprise/
# Copied train_00587_aligned.jpg → Happiness/
# Copied train_00588_aligned.jpg → Happiness/
# Copied train_00589_aligned.jpg → Surprise/
# Copied train_00590_aligned.jpg → Surprise/
# Copied train_00591_aligned.jpg → Anger/
# Copied train_00592_aligned.jpg → Happiness/
# Copied train_00593_aligned.jpg → Sadness/
# Copied train_00594_aligned.jpg → Happiness/
# Copied train_00595_aligned.jpg → Happiness/
# Copied train_00596_aligned.jpg → Anger/
# Copied train_00597_aligned.jpg → Happiness/
# Copied train_00598_aligned.jpg → Happiness/
# Copied train_00599_aligned.jpg → Happiness/
# Copied train_00600_aligned.jpg → Happiness/
# Copied train_00601_aligned.jpg → Happiness/
# Copied train_00602_aligned.jpg → Surprise/
# Copied train_00603_aligned.jpg → Sadness/
# Copied train_00604_aligned.jpg → Disgust/
# Copied train_00605_aligned.jpg → Sadness/
# Copied train_00606_aligned.jpg → Happiness/
# Copied train_00607_aligned.jpg → Disgust/
# Copied train_00608_aligned.jpg → Happiness/
# Copied train_00609_aligned.jpg → Happiness/
# Copied train_00610_aligned.jpg → Surprise/
# Copied train_00611_aligned.jpg → Sadness/
# Copied train_00612_aligned.jpg → Sadness/
# Copied train_00613_aligned.jpg → Sadness/
# Copied train_00614_aligned.jpg → Fear/
# Copied train_00615_aligned.jpg → Happiness/
# Copied train_00616_aligned.jpg → Sadness/
# Copied train_00617_aligned.jpg → Sadness/
# Copied train_00618_aligned.jpg → Surprise/
# Copied train_00619_aligned.jpg → Sadness/
# Copied train_00620_aligned.jpg → Happiness/
# Copied train_00621_aligned.jpg → Happiness/
# Copied train_00622_aligned.jpg → Sadness/
# Copied train_00623_aligned.jpg → Sadness/
# Copied train_00624_aligned.jpg → Happiness/
# Copied train_00625_aligned.jpg → Sadness/
# Copied train_00626_aligned.jpg → Surprise/
# Copied train_00627_aligned.jpg → Disgust/
# Copied train_00628_aligned.jpg → Surprise/
# Copied train_00629_aligned.jpg → Anger/
# Copied train_00630_aligned.jpg → Happiness/
# Copied train_00631_aligned.jpg → Happiness/
# Copied train_00632_aligned.jpg → Happiness/
# Copied train_00633_aligned.jpg → Happiness/
# Copied train_00634_aligned.jpg → Happiness/
# Copied train_00635_aligned.jpg → Happiness/
# Copied train_00636_aligned.jpg → Happiness/
# Copied train_00637_aligned.jpg → Surprise/
# Copied train_00638_aligned.jpg → Surprise/
# Copied train_00639_aligned.jpg → Happiness/
# Copied train_00640_aligned.jpg → Happiness/
# Copied train_00641_aligned.jpg → Anger/
# Copied train_00642_aligned.jpg → Anger/
# Copied train_00643_aligned.jpg → Sadness/
# Copied train_00644_aligned.jpg → Anger/
# Copied train_00645_aligned.jpg → Anger/
# Copied train_00646_aligned.jpg → Anger/
# Copied train_00647_aligned.jpg → Anger/
# Copied train_00648_aligned.jpg → Sadness/
# Copied train_00649_aligned.jpg → Sadness/
# Copied train_00650_aligned.jpg → Sadness/
# Copied train_00651_aligned.jpg → Sadness/
# Copied train_00652_aligned.jpg → Sadness/
# Copied train_00653_aligned.jpg → Sadness/
# Copied train_00654_aligned.jpg → Sadness/
# Copied train_00655_aligned.jpg → Sadness/
# Copied train_00656_aligned.jpg → Sadness/
# Copied train_00657_aligned.jpg → Sadness/
# Copied train_00658_aligned.jpg → Sadness/
# Copied train_00659_aligned.jpg → Sadness/
# Copied train_00660_aligned.jpg → Sadness/
# Copied train_00661_aligned.jpg → Sadness/
# Copied train_00662_aligned.jpg → Anger/
# Copied train_00663_aligned.jpg → Sadness/
# Copied train_00664_aligned.jpg → Happiness/
# Copied train_00665_aligned.jpg → Anger/
# Copied train_00666_aligned.jpg → Surprise/
# Copied train_00667_aligned.jpg → Happiness/
# Copied train_00668_aligned.jpg → Happiness/
# Copied train_00669_aligned.jpg → Happiness/
# Copied train_00670_aligned.jpg → Surprise/
# Copied train_00671_aligned.jpg → Sadness/
# Copied train_00672_aligned.jpg → Sadness/
# Copied train_00673_aligned.jpg → Surprise/
# Copied train_00674_aligned.jpg → Sadness/
# Copied train_00675_aligned.jpg → Surprise/
# Copied train_00676_aligned.jpg → Anger/
# Copied train_00677_aligned.jpg → Anger/
# Copied train_00678_aligned.jpg → Anger/
# Copied train_00679_aligned.jpg → Happiness/
# Copied train_00680_aligned.jpg → Surprise/
# Copied train_00681_aligned.jpg → Anger/
# Copied train_00682_aligned.jpg → Surprise/
# Copied train_00683_aligned.jpg → Disgust/
# Copied train_00684_aligned.jpg → Happiness/
# Copied train_00685_aligned.jpg → Surprise/
# Copied train_00686_aligned.jpg → Happiness/
# Copied train_00687_aligned.jpg → Sadness/
# Copied train_00688_aligned.jpg → Sadness/
# Copied train_00689_aligned.jpg → Happiness/
# Copied train_00690_aligned.jpg → Sadness/
# Copied train_00691_aligned.jpg → Sadness/
# Copied train_00692_aligned.jpg → Sadness/
# Copied train_00693_aligned.jpg → Anger/
# Copied train_00694_aligned.jpg → Surprise/
# Copied train_00695_aligned.jpg → Happiness/
# Copied train_00696_aligned.jpg → Happiness/
# Copied train_00697_aligned.jpg → Happiness/
# Copied train_00698_aligned.jpg → Disgust/
# Copied train_00699_aligned.jpg → Sadness/
# Copied train_00700_aligned.jpg → Happiness/
# Copied train_00701_aligned.jpg → Surprise/
# Copied train_00702_aligned.jpg → Happiness/
# Copied train_00703_aligned.jpg → Happiness/
# Copied train_00704_aligned.jpg → Happiness/
# Copied train_00705_aligned.jpg → Happiness/
# Copied train_00706_aligned.jpg → Happiness/
# Copied train_00707_aligned.jpg → Happiness/
# Copied train_00708_aligned.jpg → Happiness/
# Copied train_00709_aligned.jpg → Happiness/
# Copied train_00710_aligned.jpg → Happiness/
# Copied train_00711_aligned.jpg → Happiness/
# Copied train_00712_aligned.jpg → Sadness/
# Copied train_00713_aligned.jpg → Happiness/
# Copied train_00714_aligned.jpg → Anger/
# Copied train_00715_aligned.jpg → Happiness/
# Copied train_00716_aligned.jpg → Surprise/
# Copied train_00717_aligned.jpg → Happiness/
# Copied train_00718_aligned.jpg → Happiness/
# Copied train_00719_aligned.jpg → Happiness/
# Copied train_00720_aligned.jpg → Happiness/
# Copied train_00721_aligned.jpg → Happiness/
# Copied train_00722_aligned.jpg → Happiness/
# Copied train_00723_aligned.jpg → Sadness/
# Copied train_00724_aligned.jpg → Sadness/
# Copied train_00725_aligned.jpg → Surprise/
# Copied train_00726_aligned.jpg → Surprise/
# Copied train_00727_aligned.jpg → Surprise/
# Copied train_00728_aligned.jpg → Surprise/
# Copied train_00729_aligned.jpg → Surprise/
# Copied train_00730_aligned.jpg → Happiness/
# Copied train_00731_aligned.jpg → Sadness/
# Copied train_00732_aligned.jpg → Happiness/
# Copied train_00733_aligned.jpg → Happiness/
# Copied train_00734_aligned.jpg → Happiness/
# Copied train_00735_aligned.jpg → Happiness/
# Copied train_00736_aligned.jpg → Anger/
# Copied train_00737_aligned.jpg → Happiness/
# Copied train_00738_aligned.jpg → Sadness/
# Copied train_00739_aligned.jpg → Disgust/
# Copied train_00740_aligned.jpg → Sadness/
# Copied train_00741_aligned.jpg → Sadness/
# Copied train_00742_aligned.jpg → Surprise/
# Copied train_00743_aligned.jpg → Surprise/
# Copied train_00744_aligned.jpg → Happiness/
# Copied train_00745_aligned.jpg → Sadness/
# Copied train_00746_aligned.jpg → Anger/
# Copied train_00747_aligned.jpg → Happiness/
# Copied train_00748_aligned.jpg → Surprise/
# Copied train_00749_aligned.jpg → Anger/
# Copied train_00750_aligned.jpg → Happiness/
# Copied train_00751_aligned.jpg → Sadness/
# Copied train_00752_aligned.jpg → Sadness/
# Copied train_00753_aligned.jpg → Surprise/
# Copied train_00754_aligned.jpg → Happiness/
# Copied train_00755_aligned.jpg → Happiness/
# Copied train_00756_aligned.jpg → Surprise/
# Copied train_00757_aligned.jpg → Happiness/
# Copied train_00758_aligned.jpg → Happiness/
# Copied train_00759_aligned.jpg → Sadness/
# Copied train_00760_aligned.jpg → Happiness/
# Copied train_00761_aligned.jpg → Happiness/
# Copied train_00762_aligned.jpg → Happiness/
# Copied train_00763_aligned.jpg → Anger/
# Copied train_00764_aligned.jpg → Happiness/
# Copied train_00765_aligned.jpg → Disgust/
# Copied train_00766_aligned.jpg → Anger/
# Copied train_00767_aligned.jpg → Happiness/
# Copied train_00768_aligned.jpg → Anger/
# Copied train_00769_aligned.jpg → Surprise/
# Copied train_00770_aligned.jpg → Happiness/
# Copied train_00771_aligned.jpg → Surprise/
# Copied train_00772_aligned.jpg → Anger/
# Copied train_00773_aligned.jpg → Sadness/
# Copied train_00774_aligned.jpg → Sadness/
# Copied train_00775_aligned.jpg → Happiness/
# Copied train_00776_aligned.jpg → Anger/
# Copied train_00777_aligned.jpg → Surprise/
# Copied train_00778_aligned.jpg → Surprise/
# Copied train_00779_aligned.jpg → Fear/
# Copied train_00780_aligned.jpg → Happiness/
# Copied train_00781_aligned.jpg → Happiness/
# Copied train_00782_aligned.jpg → Surprise/
# Copied train_00783_aligned.jpg → Sadness/
# Copied train_00784_aligned.jpg → Happiness/
# Copied train_00785_aligned.jpg → Surprise/
# Copied train_00786_aligned.jpg → Sadness/
# Copied train_00787_aligned.jpg → Happiness/
# Copied train_00788_aligned.jpg → Happiness/
# Copied train_00789_aligned.jpg → Happiness/
# Copied train_00790_aligned.jpg → Anger/
# Copied train_00791_aligned.jpg → Sadness/
# Copied train_00792_aligned.jpg → Happiness/
# Copied train_00793_aligned.jpg → Surprise/
# Copied train_00794_aligned.jpg → Happiness/
# Copied train_00795_aligned.jpg → Happiness/
# Copied train_00796_aligned.jpg → Happiness/
# Copied train_00797_aligned.jpg → Happiness/
# Copied train_00798_aligned.jpg → Happiness/
# Copied train_00799_aligned.jpg → Happiness/
# Copied train_00800_aligned.jpg → Happiness/
# Copied train_00801_aligned.jpg → Happiness/
# Copied train_00802_aligned.jpg → Happiness/
# Copied train_00803_aligned.jpg → Surprise/
# Copied train_00804_aligned.jpg → Surprise/
# Copied train_00805_aligned.jpg → Happiness/
# Copied train_00806_aligned.jpg → Happiness/
# Copied train_00807_aligned.jpg → Happiness/
# Copied train_00808_aligned.jpg → Happiness/
# Copied train_00809_aligned.jpg → Sadness/
# Copied train_00810_aligned.jpg → Happiness/
# Copied train_00811_aligned.jpg → Happiness/
# Copied train_00812_aligned.jpg → Happiness/
# Copied train_00813_aligned.jpg → Happiness/
# Copied train_00814_aligned.jpg → Sadness/
# Copied train_00815_aligned.jpg → Happiness/
# Copied train_00816_aligned.jpg → Happiness/
# Copied train_00817_aligned.jpg → Sadness/
# Copied train_00818_aligned.jpg → Happiness/
# Copied train_00819_aligned.jpg → Happiness/
# Copied train_00820_aligned.jpg → Anger/
# Copied train_00821_aligned.jpg → Sadness/
# Copied train_00822_aligned.jpg → Happiness/
# Copied train_00823_aligned.jpg → Happiness/
# Copied train_00824_aligned.jpg → Happiness/
# Copied train_00825_aligned.jpg → Happiness/
# Copied train_00826_aligned.jpg → Disgust/
# Copied train_00827_aligned.jpg → Anger/
# Copied train_00828_aligned.jpg → Sadness/
# Copied train_00829_aligned.jpg → Happiness/
# Copied train_00830_aligned.jpg → Happiness/
# Copied train_00831_aligned.jpg → Happiness/
# Copied train_00832_aligned.jpg → Happiness/
# Copied train_00833_aligned.jpg → Sadness/
# Copied train_00834_aligned.jpg → Sadness/
# Copied train_00835_aligned.jpg → Sadness/
# Copied train_00836_aligned.jpg → Anger/
# Copied train_00837_aligned.jpg → Surprise/
# Copied train_00838_aligned.jpg → Happiness/
# Copied train_00839_aligned.jpg → Surprise/
# Copied train_00840_aligned.jpg → Happiness/
# Copied train_00841_aligned.jpg → Happiness/
# Copied train_00842_aligned.jpg → Sadness/
# Copied train_00843_aligned.jpg → Happiness/
# Copied train_00844_aligned.jpg → Happiness/
# Copied train_00845_aligned.jpg → Happiness/
# Copied train_00846_aligned.jpg → Anger/
# Copied train_00847_aligned.jpg → Happiness/
# Copied train_00848_aligned.jpg → Surprise/
# Copied train_00849_aligned.jpg → Happiness/
# Copied train_00850_aligned.jpg → Happiness/
# Copied train_00851_aligned.jpg → Surprise/
# Copied train_00852_aligned.jpg → Surprise/
# Copied train_00853_aligned.jpg → Sadness/
# Copied train_00854_aligned.jpg → Happiness/
# Copied train_00855_aligned.jpg → Surprise/
# Copied train_00856_aligned.jpg → Surprise/
# Copied train_00857_aligned.jpg → Surprise/
# Copied train_00858_aligned.jpg → Sadness/
# Copied train_00859_aligned.jpg → Happiness/
# Copied train_00860_aligned.jpg → Anger/
# Copied train_00861_aligned.jpg → Sadness/
# Copied train_00862_aligned.jpg → Sadness/
# Copied train_00863_aligned.jpg → Anger/
# Copied train_00864_aligned.jpg → Surprise/
# Copied train_00865_aligned.jpg → Happiness/
# Copied train_00866_aligned.jpg → Anger/
# Copied train_00867_aligned.jpg → Sadness/
# Copied train_00868_aligned.jpg → Happiness/
# Copied train_00869_aligned.jpg → Happiness/
# Copied train_00870_aligned.jpg → Happiness/
# Copied train_00871_aligned.jpg → Happiness/
# Copied train_00872_aligned.jpg → Surprise/
# Copied train_00873_aligned.jpg → Happiness/
# Copied train_00874_aligned.jpg → Happiness/
# Copied train_00875_aligned.jpg → Sadness/
# Copied train_00876_aligned.jpg → Happiness/
# Copied train_00877_aligned.jpg → Happiness/
# Copied train_00878_aligned.jpg → Sadness/
# Copied train_00879_aligned.jpg → Surprise/
# Copied train_00880_aligned.jpg → Sadness/
# Copied train_00881_aligned.jpg → Happiness/
# Copied train_00882_aligned.jpg → Happiness/
# Copied train_00883_aligned.jpg → Happiness/
# Copied train_00884_aligned.jpg → Happiness/
# Copied train_00885_aligned.jpg → Anger/
# Copied train_00886_aligned.jpg → Anger/
# Copied train_00887_aligned.jpg → Happiness/
# Copied train_00888_aligned.jpg → Happiness/
# Copied train_00889_aligned.jpg → Happiness/
# Copied train_00890_aligned.jpg → Sadness/
# Copied train_00891_aligned.jpg → Sadness/
# Copied train_00892_aligned.jpg → Sadness/
# Copied train_00893_aligned.jpg → Disgust/
# Copied train_00894_aligned.jpg → Happiness/
# Copied train_00895_aligned.jpg → Happiness/
# Copied train_00896_aligned.jpg → Happiness/
# Copied train_00897_aligned.jpg → Happiness/
# Copied train_00898_aligned.jpg → Happiness/
# Copied train_00899_aligned.jpg → Surprise/
# Copied train_00900_aligned.jpg → Anger/
# Copied train_00901_aligned.jpg → Happiness/
# Copied train_00902_aligned.jpg → Surprise/
# Copied train_00903_aligned.jpg → Happiness/
# Copied train_00904_aligned.jpg → Happiness/
# Copied train_00905_aligned.jpg → Sadness/
# Copied train_00906_aligned.jpg → Happiness/
# Copied train_00907_aligned.jpg → Disgust/
# Copied train_00908_aligned.jpg → Sadness/
# Copied train_00909_aligned.jpg → Anger/
# Copied train_00910_aligned.jpg → Happiness/
# Copied train_00911_aligned.jpg → Happiness/
# Copied train_00912_aligned.jpg → Happiness/
# Copied train_00913_aligned.jpg → Sadness/
# Copied train_00914_aligned.jpg → Surprise/
# Copied train_00915_aligned.jpg → Anger/
# Copied train_00916_aligned.jpg → Happiness/
# Copied train_00917_aligned.jpg → Happiness/
# Copied train_00918_aligned.jpg → Happiness/
# Copied train_00919_aligned.jpg → Happiness/
# Copied train_00920_aligned.jpg → Happiness/
# Copied train_00921_aligned.jpg → Sadness/
# Copied train_00922_aligned.jpg → Happiness/
# Copied train_00923_aligned.jpg → Sadness/
# Copied train_00924_aligned.jpg → Happiness/
# Copied train_00925_aligned.jpg → Happiness/
# Copied train_00926_aligned.jpg → Happiness/
# Copied train_00927_aligned.jpg → Happiness/
# Copied train_00928_aligned.jpg → Sadness/
# Copied train_00929_aligned.jpg → Anger/
# Copied train_00930_aligned.jpg → Surprise/
# Copied train_00931_aligned.jpg → Surprise/
# Copied train_00932_aligned.jpg → Happiness/
# Copied train_00933_aligned.jpg → Happiness/
# Copied train_00934_aligned.jpg → Happiness/
# Copied train_00935_aligned.jpg → Happiness/
# Copied train_00936_aligned.jpg → Happiness/
# Copied train_00937_aligned.jpg → Sadness/
# Copied train_00938_aligned.jpg → Sadness/
# Copied train_00939_aligned.jpg → Happiness/
# Copied train_00940_aligned.jpg → Happiness/
# Copied train_00941_aligned.jpg → Happiness/
# Copied train_00942_aligned.jpg → Surprise/
# Copied train_00943_aligned.jpg → Happiness/
# Copied train_00944_aligned.jpg → Happiness/
# Copied train_00945_aligned.jpg → Happiness/
# Copied train_00946_aligned.jpg → Happiness/
# Copied train_00947_aligned.jpg → Happiness/
# Copied train_00948_aligned.jpg → Surprise/
# Copied train_00949_aligned.jpg → Happiness/
# Copied train_00950_aligned.jpg → Sadness/
# Copied train_00951_aligned.jpg → Happiness/
# Copied train_00952_aligned.jpg → Anger/
# Copied train_00953_aligned.jpg → Sadness/
# Copied train_00954_aligned.jpg → Happiness/
# Copied train_00955_aligned.jpg → Happiness/
# Copied train_00956_aligned.jpg → Happiness/
# Copied train_00957_aligned.jpg → Happiness/
# Copied train_00958_aligned.jpg → Happiness/
# Copied train_00959_aligned.jpg → Happiness/
# Copied train_00960_aligned.jpg → Anger/
# Copied train_00961_aligned.jpg → Sadness/
# Copied train_00962_aligned.jpg → Anger/
# Copied train_00963_aligned.jpg → Anger/
# Copied train_00964_aligned.jpg → Happiness/
# Copied train_00965_aligned.jpg → Happiness/
# Copied train_00966_aligned.jpg → Surprise/
# Copied train_00967_aligned.jpg → Disgust/
# Copied train_00968_aligned.jpg → Sadness/
# Copied train_00969_aligned.jpg → Happiness/
# Copied train_00970_aligned.jpg → Sadness/
# Copied train_00971_aligned.jpg → Sadness/
# Copied train_00972_aligned.jpg → Happiness/
# Copied train_00973_aligned.jpg → Happiness/
# Copied train_00974_aligned.jpg → Surprise/
# Copied train_00975_aligned.jpg → Disgust/
# Copied train_00976_aligned.jpg → Happiness/
# Copied train_00977_aligned.jpg → Surprise/
# Copied train_00978_aligned.jpg → Happiness/
# Copied train_00979_aligned.jpg → Sadness/
# Copied train_00980_aligned.jpg → Happiness/
# Copied train_00981_aligned.jpg → Sadness/
# Copied train_00982_aligned.jpg → Happiness/
# Copied train_00983_aligned.jpg → Happiness/
# Copied train_00984_aligned.jpg → Happiness/
# Copied train_00985_aligned.jpg → Surprise/
# Copied train_00986_aligned.jpg → Happiness/
# Copied train_00987_aligned.jpg → Sadness/
# Copied train_00988_aligned.jpg → Happiness/
# Copied train_00989_aligned.jpg → Disgust/
# Copied train_00990_aligned.jpg → Sadness/
# Copied train_00991_aligned.jpg → Sadness/
# Copied train_00992_aligned.jpg → Sadness/
# Copied train_00993_aligned.jpg → Surprise/
# Copied train_00994_aligned.jpg → Happiness/
# Copied train_00995_aligned.jpg → Happiness/
# Copied train_00996_aligned.jpg → Happiness/
# Copied train_00997_aligned.jpg → Happiness/
# Copied train_00998_aligned.jpg → Happiness/
# Copied train_00999_aligned.jpg → Happiness/
# Copied train_01000_aligned.jpg → Surprise/
# Copied train_01001_aligned.jpg → Anger/
# Copied train_01002_aligned.jpg → Sadness/
# Copied train_01003_aligned.jpg → Surprise/
# Copied train_01004_aligned.jpg → Happiness/
# Copied train_01005_aligned.jpg → Happiness/
# Copied train_01006_aligned.jpg → Happiness/
# Copied train_01007_aligned.jpg → Disgust/
# Copied train_01008_aligned.jpg → Happiness/
# Copied train_01009_aligned.jpg → Happiness/
# Copied train_01010_aligned.jpg → Sadness/
# Copied train_01011_aligned.jpg → Sadness/
# Copied train_01012_aligned.jpg → Anger/
# Copied train_01013_aligned.jpg → Sadness/
# Copied train_01014_aligned.jpg → Happiness/
# Copied train_01015_aligned.jpg → Sadness/
# Copied train_01016_aligned.jpg → Happiness/
# Copied train_01017_aligned.jpg → Sadness/
# Copied train_01018_aligned.jpg → Happiness/
# Copied train_01019_aligned.jpg → Happiness/
# Copied train_01020_aligned.jpg → Happiness/
# Copied train_01021_aligned.jpg → Happiness/
# Copied train_01022_aligned.jpg → Happiness/
# Copied train_01023_aligned.jpg → Happiness/
# Copied train_01024_aligned.jpg → Happiness/
# Copied train_01025_aligned.jpg → Happiness/
# Copied train_01026_aligned.jpg → Happiness/
# Copied train_01027_aligned.jpg → Happiness/
# Copied train_01028_aligned.jpg → Happiness/
# Copied train_01029_aligned.jpg → Happiness/
# Copied train_01030_aligned.jpg → Anger/
# Copied train_01031_aligned.jpg → Anger/
# Copied train_01032_aligned.jpg → Happiness/
# Copied train_01033_aligned.jpg → Happiness/
# Copied train_01034_aligned.jpg → Happiness/
# Copied train_01035_aligned.jpg → Happiness/
# Copied train_01036_aligned.jpg → Happiness/
# Copied train_01037_aligned.jpg → Happiness/
# Copied train_01038_aligned.jpg → Surprise/
# Copied train_01039_aligned.jpg → Sadness/
# Copied train_01040_aligned.jpg → Anger/
# Copied train_01041_aligned.jpg → Happiness/
# Copied train_01042_aligned.jpg → Anger/
# Copied train_01043_aligned.jpg → Happiness/
# Copied train_01044_aligned.jpg → Surprise/
# Copied train_01045_aligned.jpg → Anger/
# Copied train_01046_aligned.jpg → Happiness/
# Copied train_01047_aligned.jpg → Happiness/
# Copied train_01048_aligned.jpg → Sadness/
# Copied train_01049_aligned.jpg → Sadness/
# Copied train_01050_aligned.jpg → Disgust/
# Copied train_01051_aligned.jpg → Anger/
# Copied train_01052_aligned.jpg → Anger/
# Copied train_01053_aligned.jpg → Sadness/
# Copied train_01054_aligned.jpg → Anger/
# Copied train_01055_aligned.jpg → Disgust/
# Copied train_01056_aligned.jpg → Surprise/
# Copied train_01057_aligned.jpg → Happiness/
# Copied train_01058_aligned.jpg → Happiness/
# Copied train_01059_aligned.jpg → Anger/
# Copied train_01060_aligned.jpg → Happiness/
# Copied train_01061_aligned.jpg → Happiness/
# Copied train_01062_aligned.jpg → Happiness/
# Copied train_01063_aligned.jpg → Happiness/
# Copied train_01064_aligned.jpg → Anger/
# Copied train_01065_aligned.jpg → Happiness/
# Copied train_01066_aligned.jpg → Happiness/
# Copied train_01067_aligned.jpg → Anger/
# Copied train_01068_aligned.jpg → Anger/
# Copied train_01069_aligned.jpg → Disgust/
# Copied train_01070_aligned.jpg → Sadness/
# Copied train_01071_aligned.jpg → Happiness/
# Copied train_01072_aligned.jpg → Happiness/
# Copied train_01073_aligned.jpg → Happiness/
# Copied train_01074_aligned.jpg → Sadness/
# Copied train_01075_aligned.jpg → Happiness/
# Copied train_01076_aligned.jpg → Happiness/
# Copied train_01077_aligned.jpg → Surprise/
# Copied train_01078_aligned.jpg → Sadness/
# Copied train_01079_aligned.jpg → Surprise/
# Copied train_01080_aligned.jpg → Happiness/
# Copied train_01081_aligned.jpg → Happiness/
# Copied train_01082_aligned.jpg → Happiness/
# Copied train_01083_aligned.jpg → Sadness/
# Copied train_01084_aligned.jpg → Happiness/
# Copied train_01085_aligned.jpg → Sadness/
# Copied train_01086_aligned.jpg → Surprise/
# Copied train_01087_aligned.jpg → Sadness/
# Copied train_01088_aligned.jpg → Sadness/
# Copied train_01089_aligned.jpg → Anger/
# Copied train_01090_aligned.jpg → Sadness/
# Copied train_01091_aligned.jpg → Happiness/
# Copied train_01092_aligned.jpg → Sadness/
# Copied train_01093_aligned.jpg → Sadness/
# Copied train_01094_aligned.jpg → Happiness/
# Copied train_01095_aligned.jpg → Happiness/
# Copied train_01096_aligned.jpg → Anger/
# Copied train_01097_aligned.jpg → Disgust/
# Copied train_01098_aligned.jpg → Surprise/
# Copied train_01099_aligned.jpg → Surprise/
# Copied train_01100_aligned.jpg → Sadness/
# Copied train_01101_aligned.jpg → Sadness/
# Copied train_01102_aligned.jpg → Happiness/
# Copied train_01103_aligned.jpg → Happiness/
# Copied train_01104_aligned.jpg → Anger/
# Copied train_01105_aligned.jpg → Sadness/
# Copied train_01106_aligned.jpg → Sadness/
# Copied train_01107_aligned.jpg → Surprise/
# Copied train_01108_aligned.jpg → Anger/
# Copied train_01109_aligned.jpg → Surprise/
# Copied train_01110_aligned.jpg → Surprise/
# Copied train_01111_aligned.jpg → Sadness/
# Copied train_01112_aligned.jpg → Surprise/
# Copied train_01113_aligned.jpg → Sadness/
# Copied train_01114_aligned.jpg → Happiness/
# Copied train_01115_aligned.jpg → Happiness/
# Copied train_01116_aligned.jpg → Sadness/
# Copied train_01117_aligned.jpg → Happiness/
# ...
# Copied test_2669_aligned.jpg → Neutral/
# Copied test_2670_aligned.jpg → Neutral/
# Copied test_2671_aligned.jpg → Neutral/
# Copied test_2672_aligned.jpg → Neutral/
# Copied test_2673_aligned.jpg → Neutral/
# Copied test_2674_aligned.jpg → Neutral/
# Copied test_2675_aligned.jpg → Neutral/
# Copied test_2676_aligned.jpg → Neutral/
# Copied test_2677_aligned.jpg → Neutral/
# Copied test_2678_aligned.jpg → Neutral/
# Copied test_2679_aligned.jpg → Neutral/
# Copied test_2680_aligned.jpg → Neutral/
# Copied test_2681_aligned.jpg → Neutral/
# Copied test_2682_aligned.jpg → Neutral/
# Copied test_2683_aligned.jpg → Neutral/
# Copied test_2684_aligned.jpg → Neutral/
# Copied test_2685_aligned.jpg → Neutral/
# Copied test_2686_aligned.jpg → Neutral/
# Copied test_2687_aligned.jpg → Neutral/
# Copied test_2688_aligned.jpg → Neutral/
# Copied test_2689_aligned.jpg → Neutral/
# Copied test_2690_aligned.jpg → Neutral/
# Copied test_2691_aligned.jpg → Neutral/
# Copied test_2692_aligned.jpg → Neutral/
# Copied test_2693_aligned.jpg → Neutral/
# Copied test_2694_aligned.jpg → Neutral/
# Copied test_2695_aligned.jpg → Neutral/
# Copied test_2696_aligned.jpg → Neutral/
# Copied test_2697_aligned.jpg → Neutral/
# Copied test_2698_aligned.jpg → Neutral/
# Copied test_2699_aligned.jpg → Neutral/
# Copied test_2700_aligned.jpg → Neutral/
# Copied test_2701_aligned.jpg → Neutral/
# Copied test_2702_aligned.jpg → Neutral/
# Copied test_2703_aligned.jpg → Neutral/
# Copied test_2704_aligned.jpg → Neutral/
# Copied test_2705_aligned.jpg → Neutral/
# Copied test_2706_aligned.jpg → Neutral/
# Copied test_2707_aligned.jpg → Neutral/
# Copied test_2708_aligned.jpg → Neutral/
# Copied test_2709_aligned.jpg → Neutral/
# Copied test_2710_aligned.jpg → Neutral/
# Copied test_2711_aligned.jpg → Neutral/
# Copied test_2712_aligned.jpg → Neutral/
# Copied test_2713_aligned.jpg → Neutral/
# Copied test_2714_aligned.jpg → Neutral/
# Copied test_2715_aligned.jpg → Neutral/
# Copied test_2716_aligned.jpg → Neutral/
# Copied test_2717_aligned.jpg → Neutral/
# Copied test_2718_aligned.jpg → Neutral/
# Copied test_2719_aligned.jpg → Neutral/
# Copied test_2720_aligned.jpg → Neutral/
# Copied test_2721_aligned.jpg → Neutral/
# Copied test_2722_aligned.jpg → Neutral/
# Copied test_2723_aligned.jpg → Neutral/
# Copied test_2724_aligned.jpg → Neutral/
# Copied test_2725_aligned.jpg → Neutral/
# Copied test_2726_aligned.jpg → Neutral/
# Copied test_2727_aligned.jpg → Neutral/
# Copied test_2728_aligned.jpg → Neutral/
# Copied test_2729_aligned.jpg → Neutral/
# Copied test_2730_aligned.jpg → Neutral/
# Copied test_2731_aligned.jpg → Neutral/
# Copied test_2732_aligned.jpg → Neutral/
# Copied test_2733_aligned.jpg → Neutral/
# Copied test_2734_aligned.jpg → Neutral/
# Copied test_2735_aligned.jpg → Neutral/
# Copied test_2736_aligned.jpg → Neutral/
# Copied test_2737_aligned.jpg → Neutral/
# Copied test_2738_aligned.jpg → Neutral/
# Copied test_2739_aligned.jpg → Neutral/
# Copied test_2740_aligned.jpg → Neutral/
# Copied test_2741_aligned.jpg → Neutral/
# Copied test_2742_aligned.jpg → Neutral/
# Copied test_2743_aligned.jpg → Neutral/
# Copied test_2744_aligned.jpg → Neutral/
# Copied test_2745_aligned.jpg → Neutral/
# Copied test_2746_aligned.jpg → Neutral/
# Copied test_2747_aligned.jpg → Neutral/
# Copied test_2748_aligned.jpg → Neutral/
# Copied test_2749_aligned.jpg → Neutral/
# Copied test_2750_aligned.jpg → Neutral/
# Copied test_2751_aligned.jpg → Neutral/
# Copied test_2752_aligned.jpg → Neutral/
# Copied test_2753_aligned.jpg → Neutral/
# Copied test_2754_aligned.jpg → Neutral/
# Copied test_2755_aligned.jpg → Neutral/
# Copied test_2756_aligned.jpg → Neutral/
# Copied test_2757_aligned.jpg → Neutral/
# Copied test_2758_aligned.jpg → Neutral/
# Copied test_2759_aligned.jpg → Neutral/
# Copied test_2760_aligned.jpg → Neutral/
# Copied test_2761_aligned.jpg → Neutral/
# Copied test_2762_aligned.jpg → Neutral/
# Copied test_2763_aligned.jpg → Neutral/
# Copied test_2764_aligned.jpg → Neutral/
# Copied test_2765_aligned.jpg → Neutral/
# Copied test_2766_aligned.jpg → Neutral/
# Copied test_2767_aligned.jpg → Neutral/
# Copied test_2768_aligned.jpg → Neutral/
# Copied test_2769_aligned.jpg → Neutral/
# Copied test_2770_aligned.jpg → Neutral/
# Copied test_2771_aligned.jpg → Neutral/
# Copied test_2772_aligned.jpg → Neutral/
# Copied test_2773_aligned.jpg → Neutral/
# Copied test_2774_aligned.jpg → Neutral/
# Copied test_2775_aligned.jpg → Neutral/
# Copied test_2776_aligned.jpg → Neutral/
# Copied test_2777_aligned.jpg → Neutral/
# Copied test_2778_aligned.jpg → Neutral/
# Copied test_2779_aligned.jpg → Neutral/
# Copied test_2780_aligned.jpg → Neutral/
# Copied test_2781_aligned.jpg → Neutral/
# Copied test_2782_aligned.jpg → Neutral/
# Copied test_2783_aligned.jpg → Neutral/
# Copied test_2784_aligned.jpg → Neutral/
# Copied test_2785_aligned.jpg → Neutral/
# Copied test_2786_aligned.jpg → Neutral/
# Copied test_2787_aligned.jpg → Neutral/
# Copied test_2788_aligned.jpg → Neutral/
# Copied test_2789_aligned.jpg → Neutral/
# Copied test_2790_aligned.jpg → Neutral/
# Copied test_2791_aligned.jpg → Neutral/
# Copied test_2792_aligned.jpg → Neutral/
# Copied test_2793_aligned.jpg → Neutral/
# Copied test_2794_aligned.jpg → Neutral/
# Copied test_2795_aligned.jpg → Neutral/
# Copied test_2796_aligned.jpg → Neutral/
# Copied test_2797_aligned.jpg → Neutral/
# Copied test_2798_aligned.jpg → Neutral/
# Copied test_2799_aligned.jpg → Neutral/
# Copied test_2800_aligned.jpg → Neutral/
# Copied test_2801_aligned.jpg → Neutral/
# Copied test_2802_aligned.jpg → Neutral/
# Copied test_2803_aligned.jpg → Neutral/
# Copied test_2804_aligned.jpg → Neutral/
# Copied test_2805_aligned.jpg → Neutral/
# Copied test_2806_aligned.jpg → Neutral/
# Copied test_2807_aligned.jpg → Neutral/
# Copied test_2808_aligned.jpg → Neutral/
# Copied test_2809_aligned.jpg → Neutral/
# Copied test_2810_aligned.jpg → Neutral/
# Copied test_2811_aligned.jpg → Neutral/
# Copied test_2812_aligned.jpg → Neutral/
# Copied test_2813_aligned.jpg → Neutral/
# Copied test_2814_aligned.jpg → Neutral/
# Copied test_2815_aligned.jpg → Neutral/
# Copied test_2816_aligned.jpg → Neutral/
# Copied test_2817_aligned.jpg → Neutral/
# Copied test_2818_aligned.jpg → Neutral/
# Copied test_2819_aligned.jpg → Neutral/
# Copied test_2820_aligned.jpg → Neutral/
# Copied test_2821_aligned.jpg → Neutral/
# Copied test_2822_aligned.jpg → Neutral/
# Copied test_2823_aligned.jpg → Neutral/
# Copied test_2824_aligned.jpg → Neutral/
# Copied test_2825_aligned.jpg → Neutral/
# Copied test_2826_aligned.jpg → Neutral/
# Copied test_2827_aligned.jpg → Neutral/
# Copied test_2828_aligned.jpg → Neutral/
# Copied test_2829_aligned.jpg → Neutral/
# Copied test_2830_aligned.jpg → Neutral/
# Copied test_2831_aligned.jpg → Neutral/
# Copied test_2832_aligned.jpg → Neutral/
# Copied test_2833_aligned.jpg → Neutral/
# Copied test_2834_aligned.jpg → Neutral/
# Copied test_2835_aligned.jpg → Neutral/
# Copied test_2836_aligned.jpg → Neutral/
# Copied test_2837_aligned.jpg → Neutral/
# Copied test_2838_aligned.jpg → Neutral/
# Copied test_2839_aligned.jpg → Neutral/
# Copied test_2840_aligned.jpg → Neutral/
# Copied test_2841_aligned.jpg → Neutral/
# Copied test_2842_aligned.jpg → Neutral/
# Copied test_2843_aligned.jpg → Neutral/
# Copied test_2844_aligned.jpg → Neutral/
# Copied test_2845_aligned.jpg → Neutral/
# Copied test_2846_aligned.jpg → Neutral/
# Copied test_2847_aligned.jpg → Neutral/
# Copied test_2848_aligned.jpg → Neutral/
# Copied test_2849_aligned.jpg → Neutral/
# Copied test_2850_aligned.jpg → Neutral/
# Copied test_2851_aligned.jpg → Neutral/
# Copied test_2852_aligned.jpg → Neutral/
# Copied test_2853_aligned.jpg → Neutral/
# Copied test_2854_aligned.jpg → Neutral/
# Copied test_2855_aligned.jpg → Neutral/
# Copied test_2856_aligned.jpg → Neutral/
# Copied test_2857_aligned.jpg → Neutral/
# Copied test_2858_aligned.jpg → Neutral/
# Copied test_2859_aligned.jpg → Neutral/
# Copied test_2860_aligned.jpg → Neutral/
# Copied test_2861_aligned.jpg → Neutral/
# Copied test_2862_aligned.jpg → Neutral/
# Copied test_2863_aligned.jpg → Neutral/
# Copied test_2864_aligned.jpg → Neutral/
# Copied test_2865_aligned.jpg → Neutral/
# Copied test_2866_aligned.jpg → Neutral/
# Copied test_2867_aligned.jpg → Neutral/
# Copied test_2868_aligned.jpg → Neutral/
# Copied test_2869_aligned.jpg → Neutral/
# Copied test_2870_aligned.jpg → Neutral/
# Copied test_2871_aligned.jpg → Neutral/
# Copied test_2872_aligned.jpg → Neutral/
# Copied test_2873_aligned.jpg → Neutral/
# Copied test_2874_aligned.jpg → Neutral/
# Copied test_2875_aligned.jpg → Neutral/
# Copied test_2876_aligned.jpg → Neutral/
# Copied test_2877_aligned.jpg → Neutral/
# Copied test_2878_aligned.jpg → Neutral/
# Copied test_2879_aligned.jpg → Neutral/
# Copied test_2880_aligned.jpg → Neutral/
# Copied test_2881_aligned.jpg → Neutral/
# Copied test_2882_aligned.jpg → Neutral/
# Copied test_2883_aligned.jpg → Neutral/
# Copied test_2884_aligned.jpg → Neutral/
# Copied test_2885_aligned.jpg → Neutral/
# Copied test_2886_aligned.jpg → Neutral/
# Copied test_2887_aligned.jpg → Neutral/
# Copied test_2888_aligned.jpg → Neutral/
# Copied test_2889_aligned.jpg → Neutral/
# Copied test_2890_aligned.jpg → Neutral/
# Copied test_2891_aligned.jpg → Neutral/
# Copied test_2892_aligned.jpg → Neutral/
# Copied test_2893_aligned.jpg → Neutral/
# Copied test_2894_aligned.jpg → Neutral/
# Copied test_2895_aligned.jpg → Neutral/
# Copied test_2896_aligned.jpg → Neutral/
# Copied test_2897_aligned.jpg → Neutral/
# Copied test_2898_aligned.jpg → Neutral/
# Copied test_2899_aligned.jpg → Neutral/
# Copied test_2900_aligned.jpg → Neutral/
# Copied test_2901_aligned.jpg → Neutral/
# Copied test_2902_aligned.jpg → Neutral/
# Copied test_2903_aligned.jpg → Neutral/
# Copied test_2904_aligned.jpg → Neutral/
# Copied test_2905_aligned.jpg → Neutral/
# Copied test_2906_aligned.jpg → Neutral/
# Copied test_2907_aligned.jpg → Neutral/
# Copied test_2908_aligned.jpg → Neutral/
# Copied test_2909_aligned.jpg → Neutral/
# Copied test_2910_aligned.jpg → Neutral/
# Copied test_2911_aligned.jpg → Neutral/
# Copied test_2912_aligned.jpg → Neutral/
# Copied test_2913_aligned.jpg → Neutral/
# Copied test_2914_aligned.jpg → Neutral/
# Copied test_2915_aligned.jpg → Neutral/
# Copied test_2916_aligned.jpg → Neutral/
# Copied test_2917_aligned.jpg → Neutral/
# Copied test_2918_aligned.jpg → Neutral/
# Copied test_2919_aligned.jpg → Neutral/
# Copied test_2920_aligned.jpg → Neutral/
# Copied test_2921_aligned.jpg → Neutral/
# Copied test_2922_aligned.jpg → Neutral/
# Copied test_2923_aligned.jpg → Neutral/
# Copied test_2924_aligned.jpg → Neutral/
# Copied test_2925_aligned.jpg → Neutral/
# Copied test_2926_aligned.jpg → Neutral/
# Copied test_2927_aligned.jpg → Neutral/
# Copied test_2928_aligned.jpg → Neutral/
# Copied test_2929_aligned.jpg → Neutral/
# Copied test_2930_aligned.jpg → Neutral/
# Copied test_2931_aligned.jpg → Neutral/
# Copied test_2932_aligned.jpg → Neutral/
# Copied test_2933_aligned.jpg → Neutral/
# Copied test_2934_aligned.jpg → Neutral/
# Copied test_2935_aligned.jpg → Neutral/
# Copied test_2936_aligned.jpg → Neutral/
# Copied test_2937_aligned.jpg → Neutral/
# Copied test_2938_aligned.jpg → Neutral/
# Copied test_2939_aligned.jpg → Neutral/
# Copied test_2940_aligned.jpg → Neutral/
# Copied test_2941_aligned.jpg → Neutral/
# Copied test_2942_aligned.jpg → Neutral/
# Copied test_2943_aligned.jpg → Neutral/
# Copied test_2944_aligned.jpg → Neutral/
# Copied test_2945_aligned.jpg → Neutral/
# Copied test_2946_aligned.jpg → Neutral/
# Copied test_2947_aligned.jpg → Neutral/
# Copied test_2948_aligned.jpg → Neutral/
# Copied test_2949_aligned.jpg → Neutral/
# Copied test_2950_aligned.jpg → Neutral/
# Copied test_2951_aligned.jpg → Neutral/
# Copied test_2952_aligned.jpg → Neutral/
# Copied test_2953_aligned.jpg → Neutral/
# Copied test_2954_aligned.jpg → Neutral/
# Copied test_2955_aligned.jpg → Neutral/
# Copied test_2956_aligned.jpg → Neutral/
# Copied test_2957_aligned.jpg → Neutral/
# Copied test_2958_aligned.jpg → Neutral/
# Copied test_2959_aligned.jpg → Neutral/
# Copied test_2960_aligned.jpg → Neutral/
# Copied test_2961_aligned.jpg → Neutral/
# Copied test_2962_aligned.jpg → Neutral/
# Copied test_2963_aligned.jpg → Neutral/
# Copied test_2964_aligned.jpg → Neutral/
# Copied test_2965_aligned.jpg → Neutral/
# Copied test_2966_aligned.jpg → Neutral/
# Copied test_2967_aligned.jpg → Neutral/
# Copied test_2968_aligned.jpg → Neutral/
# Copied test_2969_aligned.jpg → Neutral/
# Copied test_2970_aligned.jpg → Neutral/
# Copied test_2971_aligned.jpg → Neutral/
# Copied test_2972_aligned.jpg → Neutral/
# Copied test_2973_aligned.jpg → Neutral/
# Copied test_2974_aligned.jpg → Neutral/
# Copied test_2975_aligned.jpg → Neutral/
# Copied test_2976_aligned.jpg → Neutral/
# Copied test_2977_aligned.jpg → Neutral/
# Copied test_2978_aligned.jpg → Neutral/
# Copied test_2979_aligned.jpg → Neutral/
# Copied test_2980_aligned.jpg → Neutral/
# Copied test_2981_aligned.jpg → Neutral/
# Copied test_2982_aligned.jpg → Neutral/
# Copied test_2983_aligned.jpg → Neutral/
# Copied test_2984_aligned.jpg → Neutral/
# Copied test_2985_aligned.jpg → Neutral/
# Copied test_2986_aligned.jpg → Neutral/
# Copied test_2987_aligned.jpg → Neutral/
# Copied test_2988_aligned.jpg → Neutral/
# Copied test_2989_aligned.jpg → Neutral/
# Copied test_2990_aligned.jpg → Neutral/
# Copied test_2991_aligned.jpg → Neutral/
# Copied test_2992_aligned.jpg → Neutral/
# Copied test_2993_aligned.jpg → Neutral/
# Copied test_2994_aligned.jpg → Neutral/
# Copied test_2995_aligned.jpg → Neutral/
# Copied test_2996_aligned.jpg → Neutral/
# Copied test_2997_aligned.jpg → Neutral/
# Copied test_2998_aligned.jpg → Neutral/
# Copied test_2999_aligned.jpg → Neutral/
# Copied test_3000_aligned.jpg → Neutral/
# Copied test_3001_aligned.jpg → Neutral/
# Copied test_3002_aligned.jpg → Neutral/
# Copied test_3003_aligned.jpg → Neutral/
# Copied test_3004_aligned.jpg → Neutral/
# Copied test_3005_aligned.jpg → Neutral/
# Copied test_3006_aligned.jpg → Neutral/
# Copied test_3007_aligned.jpg → Neutral/
# Copied test_3008_aligned.jpg → Neutral/
# Copied test_3009_aligned.jpg → Neutral/
# Copied test_3010_aligned.jpg → Neutral/
# Copied test_3011_aligned.jpg → Neutral/
# Copied test_3012_aligned.jpg → Neutral/
# Copied test_3013_aligned.jpg → Neutral/
# Copied test_3014_aligned.jpg → Neutral/
# Copied test_3015_aligned.jpg → Neutral/
# Copied test_3016_aligned.jpg → Neutral/
# Copied test_3017_aligned.jpg → Neutral/
# Copied test_3018_aligned.jpg → Neutral/
# Copied test_3019_aligned.jpg → Neutral/
# Copied test_3020_aligned.jpg → Neutral/
# Copied test_3021_aligned.jpg → Neutral/
# Copied test_3022_aligned.jpg → Neutral/
# Copied test_3023_aligned.jpg → Neutral/
# Copied test_3024_aligned.jpg → Neutral/
# Copied test_3025_aligned.jpg → Neutral/
# Copied test_3026_aligned.jpg → Neutral/
# Copied test_3027_aligned.jpg → Neutral/
# Copied test_3028_aligned.jpg → Neutral/
# Copied test_3029_aligned.jpg → Neutral/
# Copied test_3030_aligned.jpg → Neutral/
# Copied test_3031_aligned.jpg → Neutral/
# Copied test_3032_aligned.jpg → Neutral/
# Copied test_3033_aligned.jpg → Neutral/
# Copied test_3034_aligned.jpg → Neutral/
# Copied test_3035_aligned.jpg → Neutral/
# Copied test_3036_aligned.jpg → Neutral/
# Copied test_3037_aligned.jpg → Neutral/
# Copied test_3038_aligned.jpg → Neutral/
# Copied test_3039_aligned.jpg → Neutral/
# Copied test_3040_aligned.jpg → Neutral/
# Copied test_3041_aligned.jpg → Neutral/
# Copied test_3042_aligned.jpg → Neutral/
# Copied test_3043_aligned.jpg → Neutral/
# Copied test_3044_aligned.jpg → Neutral/
# Copied test_3045_aligned.jpg → Neutral/
# Copied test_3046_aligned.jpg → Neutral/
# Copied test_3047_aligned.jpg → Neutral/
# Copied test_3048_aligned.jpg → Neutral/
# Copied test_3049_aligned.jpg → Neutral/
# Copied test_3050_aligned.jpg → Neutral/
# Copied test_3051_aligned.jpg → Neutral/
# Copied test_3052_aligned.jpg → Neutral/
# Copied test_3053_aligned.jpg → Neutral/
# Copied test_3054_aligned.jpg → Neutral/
# Copied test_3055_aligned.jpg → Neutral/
# Copied test_3056_aligned.jpg → Neutral/
# Copied test_3057_aligned.jpg → Neutral/
# Copied test_3058_aligned.jpg → Neutral/
# Copied test_3059_aligned.jpg → Neutral/
# Copied test_3060_aligned.jpg → Neutral/
# Copied test_3061_aligned.jpg → Neutral/
# Copied test_3062_aligned.jpg → Neutral/
# Copied test_3063_aligned.jpg → Neutral/
# Copied test_3064_aligned.jpg → Neutral/
# Copied test_3065_aligned.jpg → Neutral/
# Copied test_3066_aligned.jpg → Neutral/
# Copied test_3067_aligned.jpg → Neutral/
# Copied test_3068_aligned.jpg → Neutral/
